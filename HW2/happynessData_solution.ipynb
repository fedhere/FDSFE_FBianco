# %% [markdown]
# <a href="https://colab.research.google.com/github/fedhere/FDSfE_FBianco/blob/main/HW2/happynessData_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
happiness15 = pd.read_csv("2015.csv")

# %%
happiness15["year"] = 2015
happiness15.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
t19.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption  year
# 0                      0.393  2019
# 1                      0.410  2019
# ...

# %%
addtot15 = t19.loc[t19["Country or region"].isin(["Gambia", "Namibia"])].rename(columns={"Overall rank":'Happiness Rank',
    'Country or region':'Country', 'Score':'Happiness Score', 'GDP per capita':'Economy (GDP per Capita)',
       'Healthy life expectancy':'Health (Life Expectancy)',
       'Freedom to make life choices':'Freedom', 
       'Perceptions of corruption':'Trust (Government Corruption)'})

# %%
happiness15.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
happiness15.drop("Happiness Rank", axis=1)
# Out:
#          Country                           Region  Happiness Score  \
# 0    Switzerland                   Western Europe            7.587
# 1        Iceland                   Western Europe            7.561
# 2        Denmark                   Western Europe            7.527
# 3         Norway                   Western Europe            7.522
# 4         Canada                    North America            7.427
# ..           ...                              ...              ...
# 153       Rwanda               Sub-Saharan Africa            3.465
# 154        Benin               Sub-Saharan Africa            3.340
# 155        Syria  Middle East and Northern Africa            3.006
# 156      Burundi               Sub-Saharan Africa            2.905
# 157         Togo               Sub-Saharan Africa            2.839
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# ...

# %%
happiness = pd.concat([happiness15,addtot15])

# %%
happiness.drop(["Social support", "Happiness Rank"], axis=1, inplace=True)

# %%
happiness.corr()
# Out:
#                                Happiness Score  Standard Error  \
# Happiness Score                       1.000000       -0.177254
# Standard Error                       -0.177254        1.000000
# Economy (GDP per Capita)              0.780130       -0.217651
# Family                                0.740605       -0.120728
# Health (Life Expectancy)              0.725936       -0.310287
# Freedom                               0.568437       -0.129773
# Trust (Government Corruption)         0.395285       -0.178325
# Generosity                            0.182865       -0.088439
# Dystopia Residual                     0.530474        0.083981
# year                                 -0.077951             NaN
#
#                                Economy (GDP per Capita)    Family  \
# Happiness Score                                0.780130  0.740605
# Standard Error                                -0.217651 -0.120728
# Economy (GDP per Capita)                       1.000000  0.645299
# ...

# %%
import pylab as plt
plt.imshow(happiness.corr(), cmap='RdBu', clim=[-1,1])
plt.colorbar()

# %% [markdown]
# Following the work we did together on the youtube videos and movies datasets, explore this dataset of "world happiness".
#
# On your own, perform the following tasks and report the results (with neat print statemnets as done in https://github.com/fedhere/FDSfE_FBianco/blob/main/HW2/movies_exploratory_instructions.ipynb).
#
# - find the shape of the dataframe
# - show the top _10 rows_ and bottom _10 rows_ of the dataframe
# - inspect if the dataframe has missing values. If it does decide ifyou want to remove the rows or columns (with _drop_ or _dropna_ as we did in the movies assignment, or replace them with some value that you thin is appropriate, for example with with _fillna_, see instructions on this function [here](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.fillna.html)). The choice of how to deal with missing values is yours, but you do have to end up with a dataframe with no missing values.
# - find the happines in a country of your choice, for example your country of origin.
# - find the happiest country.
# - is the happiest country also the top country in any of the following variables: [Economy (GDP per Capita),	Family	Health, (Life Expectancy),	Freedom	Trust (Government Corruption),Generosity	Dystopia Residual]
# - measure the correlation among (numerical) variables
# - show a plot of the correlation of (numerical) variables (we did it in a couple of different ways in the youtube videos notebook) and describe it in a caption - what do you see? any noticeable correlations or anticorrelations?

# %%
happiness.to_csv("happines.csv", index=False)

# %%
happiness.groupby("Region").max().sort_values(by="Generosity", ascending=False)
# Out:
#                                         Country  Happiness Score  \
# Region
# Southeastern Asia                       Vietnam            6.798
# Western Europe                   United Kingdom            7.587
# Sub-Saharan Africa                     Zimbabwe            5.477
# Southern Asia                         Sri Lanka            5.253
# Australia and New Zealand           New Zealand            7.286
# Middle East and Northern Africa           Yemen            7.278
# Latin America and Caribbean           Venezuela            7.226
# North America                     United States            7.427
# Eastern Asia                             Taiwan            6.298
# Central and Eastern Europe           Uzbekistan            6.505
#
#                                  Standard Error  Economy (GDP per Capita)  \
# Region
# Southeastern Asia                       0.06698                   1.52186
# Western Europe                          0.05635                   1.56391
# ...
